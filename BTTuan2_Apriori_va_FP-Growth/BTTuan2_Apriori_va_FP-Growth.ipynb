# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics

# %% [markdown]
# Câu 1

# %% [markdown]
# Nhập dữ liệu đầu vào và cho biết số lượng dữ liệu huấn luyện

# %%
train = pd.read_csv("adult.data.csv")
test = pd.read_csv("adult.test.csv")

# %% [markdown]
# Câu 2

# %% [markdown]
# Xóa những dòng có chứa dữ liệu trống

# %% [markdown]
# Xóa cột final weight ‘fnlwgt’ trong dữ liệu huấn luyện

# %% [markdown]
# Nối dữ liệu huấn luyện và kiểm thử lại với nhau

# %%
df = pd.concat([train,test])

# %%
df
# Out:
#        age          workclass   education  education-num       marital-status  \
# 0       39          State-gov   Bachelors             13        Never-married
# 1       50   Self-emp-not-inc   Bachelors             13   Married-civ-spouse
# 2       38            Private     HS-grad              9             Divorced
# 3       53            Private        11th              7   Married-civ-spouse
# 4       28            Private   Bachelors             13   Married-civ-spouse
# ...    ...                ...         ...            ...                  ...
# 16276   39            Private   Bachelors             13             Divorced
# 16277   64                  ?     HS-grad              9              Widowed
# 16278   38            Private   Bachelors             13   Married-civ-spouse
# 16279   44            Private   Bachelors             13             Divorced
# 16280   35       Self-emp-inc   Bachelors             13   Married-civ-spouse
#
# ...
